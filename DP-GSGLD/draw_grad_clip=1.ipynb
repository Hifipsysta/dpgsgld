# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
# Out:
# In /Users/yangchengyi/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /Users/yangchengyi/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /Users/yangchengyi/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /Users/yangchengyi/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# ...

# %%
plt.rcParams['font.sans-serif'] = ['SimHei'] 
plt.rcParams['axes.unicode_minus'] = False

# %%
def open_from_pickle(head_path, save_dir, save_data):
    save_path = head_path + '/' + save_dir + '/' + save_data + '.pickle'
    save_file = open(save_path, 'rb')
    return pickle.load(save_file)

# %%
gradient_norm_history_DPGSGLD = open_from_pickle(head_path = 'assets', 
                 save_dir = 'grad_log_clip=1', 
                 save_data = 'gradient_norm_history_DPGSGLD')

# %%
len(gradient_norm_history_DPGSGLD)
# Out:
# 310

# %%
gradient_norm_history_DPSGD = open_from_pickle(head_path = 'assets', 
                 save_dir = 'grad_log_clip=1', 
                 save_data = 'gradient_norm_history_DPSGD')

# %%
len(gradient_norm_history_DPSGD)
# Out:
# 310

# %%
gradient_norm_history_DPSGLD = open_from_pickle(head_path = 'assets', 
                 save_dir = 'grad_log_clip=1', 
                 save_data = 'gradient_norm_history_DPSGLD')

# %%
len(gradient_norm_history_DPSGLD)
# Out:
# 310

# %%
import matplotlib.ticker as mtick
fmt='%.f%%'
yticks = mtick.FormatStrFormatter(fmt)

# %%
idx_history = [i+1 for i in range(len(gradient_norm_history_DPGSGLD))]

# %%
len(idx_history)
# Out:
# 310

# %% [markdown]
# plt.figure(figsize=(18,6))
# plt.plot(idx_history, gradient_norm_history_DPSGD)
# plt.xticks(fontsize=17)
# plt.yticks(fontsize=17)
# plt.xlabel('运算次数', fontsize=18)
# plt.ylabel('梯度范数', fontsize=18)

# %% [markdown]
# plt.figure(figsize=(18,6))
# plt.plot(idx_history, gradient_norm_history_DPGSGLD)
# plt.xticks(fontsize=17)
# plt.yticks(fontsize=17)
# plt.xlabel('运算次数', fontsize=18)
# plt.ylabel('梯度范数', fontsize=18)

# %% [markdown]
# plt.figure(figsize=(18,6))
# plt.plot(idx_history, gradient_norm_history_DPSGLD)
# plt.xticks(fontsize=17)
# plt.yticks(fontsize=17)
# plt.xlabel('运算次数', fontsize=18)
# plt.ylabel('梯度范数', fontsize=18)

# %%
plt.figure(figsize=(18,6))
plt.plot(idx_history, gradient_norm_history_DPSGD)
plt.plot(idx_history, gradient_norm_history_DPSGLD)
plt.plot(idx_history, gradient_norm_history_DPGSGLD)
plt.xticks(fontsize=17)
plt.yticks(fontsize=17)
plt.xlabel('Number of operations', fontsize=18)
plt.ylabel('Gradient Norm', fontsize=18)
# Out:
# Text(0, 0.5, 'Gradient Norm')

# %%
plt.figure(figsize=(10,8))
plt.figure(1)
ax1 = plt.subplot(311)
plt.plot(idx_history, gradient_norm_history_DPSGLD, label='DP-SGLD')
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
#plt.xlabel('Number of operations')
plt.ylabel('Gradient Norm',fontsize=18)
plt.legend(loc=1,fontsize=16)

ax1 = plt.subplot(312)
plt.plot(idx_history, gradient_norm_history_DPSGD, label='DP-SGD')
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
565506, 0.06629912555217743, 0.9999996423721313, 0.06131688877940178, 0.04884839430451393, 0.9999995827674866, 0.03718414157629013, 0.027366595342755318, 0.9999994039535522, 0.031475458294153214, 0.029624439775943756, 0.9999992251396179, 0.02823200263082981, 0.020342066884040833, 0.9999991655349731, 0.02218162640929222, 0.023271679878234863, 0.9999993443489075, 0.022484678775072098, 0.0187348835170269, 0.3758050203323364, 0.02378552220761776, 0.0187348835170269, 0.9999992847442627, 0.021001117303967476, 0.01792171411216259, 0.9999991059303284, 0.017086036503314972, 0.012321649119257927, 0.9999991655349731, 0.01769268326461315, 0.015907952561974525, 0.9999993443489075, 0.017323674634099007, 0.015749283134937286, 0.36521148681640625, 0.01733003929257393, 0.015749283134937286, 0.9999993443489075, 0.014579360373318195, 0.012782193720340729, 0.9999991655349731, 0.013032053597271442, 0.009671872481703758, 0.9999992847442627, 0.01425541564822197, 0.012300822883844376, 0.999999463558197, 0.04033367335796356, 0.06536047905683517, 0.44232386350631714, 0.038444291800260544, 0.06536047905683517, 0.9999994039535522, 0.0128730284050107, 0.010819305665791035, 0.9999993443489075, 0.049890484660863876, 0.10663687437772751, 0.9999998211860657, 0.2873694896697998]

# %%
len(DPSGD_grad)
# Out:
# 310

# %%
DPSGD_exa=[]
for val in  DPSGD_grad:
    if val>1:
        DPSGD_exa.append(val)
    else:
        pass

# %%
len(DPSGD_exa)
# Out:
# 3

# %%
DPSGLD_exa=[]
for val in DPSGLD_grad:
    if val>1:
        DPSGLD_exa.append(val)
    else:
        pass

# %%
len(DPSGLD_exa)
# Out:
# 90

# %%
DPGSGLD_exa=[]
for val in DPGSGLD_grad:
    if val>1:
        DPGSGLD_exa.append(val)
    else:
        pass

# %%
len(DPGSGLD_exa)
# Out:
# 0

# %%
bar_data1=[310-len(DPSGLD_exa),
          310-len(DPSGD_exa),
          310-len(DPGSGLD_exa)]
bar_data2=[len(DPSGLD_exa),
          len(DPSGD_exa),
           len(DPGSGLD_exa)]

# %%
bar_labels = ['DP-SGLD','DP-SGD','DP-GSGLD']

# %%
plt.figure
x = np.arange(len(bar_data1))  # x轴刻度标签位置
width = 0.25  # 柱子的宽度
# 计算每个柱子在x轴上的位置，保证x轴刻度标签居中
# x - width/2，x + width/2即每组数据在x轴上的位置

plt.bar(x - width/2, bar_data1, width, label='$\leq 1$',color='steelblue')
plt.bar(x + width/2,  bar_data2, width, label='$> 1$',color='darkorange')
plt.ylabel('Number of Elements',fontsize=14)
plt.legend(fontsize=12)
plt.xticks(x, labels=bar_labels,fontsize=13)
plt.yticks(fontsize=13)
plt.ylim(0,340)
for a,b in zip(x + width/2,bar_data2):
    plt.text(a, b+1.8, '%.0f' % b, ha='center', va="bottom",fontsize=12)
for a,b in zip(x - width/2,bar_data1):
    plt.text(a, b+1.8, '%.0f' % b, ha='center', va="bottom",fontsize=12)
